# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_for_EPLPassing = pd.read_csv("ChelseaEPL20-21PassesForMatchStats.csv", encoding='ISO-8859-1')
df_for_EPLPassing.head()
# Out:
#          Date        Round  Manager Venue Result  GF  GA        Opponent  \
# 0  14/09/2020  Matchweek 1  Lampard  Away      W   3   1        Brighton
# 1  20/09/2020  Matchweek 2  Lampard  Home      L   0   2       Liverpool
# 2  26/09/2020  Matchweek 3  Lampard  Away      D   3   3       West Brom
# 3  03/10/2020  Matchweek 4  Lampard  Home      W   4   0  Crystal Palace
# 4  17/10/2020  Matchweek 5  Lampard  Home      D   3   3     Southampton
#
#    Total Passes Completed  Total Attempted Passes  ...  Long Passes Completed  \
# 0                     402                     484  ...                     59
# 1                     439                     518  ...                     68
# 2                     732                     837  ...                     74
# 3                     650                     736  ...                    103
# 4                     500                     612  ...                     60
#
# ...

# %%
df_for_EPLPossession = pd.read_csv("ChelseaCL20-21PossessionForMatchStats.csv", encoding='ISO-8859-1')
df_for_EPLPossession.head()
# Out:
#       Team        Date        Round  Manager Venue Result  GF  GA   Opponent  \
# 0  Chelsea  20/10/2020  Group stage  Lampard  Home      D   0   0    Sevilla
# 1  Chelsea  28/10/2020  Group stage  Lampard  Away      W   4   0  Krasnodar
# 2  Chelsea  04/11/2020  Group stage  Lampard  Home      W   3   0     Rennes
# 3  Chelsea  24/11/2020  Group stage  Lampard  Away      W   2   1     Rennes
# 4  Chelsea  02/12/2020  Group stage  Lampard  Away      W   4   0    Sevilla
#
#    Possession  ...  Progressive Distnace Of Ball Carries  \
# 0          44  ...                                   847
# 1          70  ...                                  1473
# 2          57  ...                                  1498
# 3          49  ...                                   822
# 4          45  ...                                  1054
#
#    Carries Into Midfield 3rd + Attacking 3rd  \
# 0                                         38
# 1                                         47
# ...

# %%
df_for_CLPassing = pd.read_csv("ChelseaCL20-21PassesForMatchStats.csv", encoding='ISO-8859-1')
df_for_CLPassing.head()
# Out:
#       Team        Date        Round  Manager Venue Result  GF  GA   Opponent  \
# 0  Chelsea  20/10/2020  Group stage  Lampard  Home      D   0   0    Sevilla
# 1  Chelsea  28/10/2020  Group stage  Lampard  Away      W   4   0  Krasnodar
# 2  Chelsea  04/11/2020  Group stage  Lampard  Home      W   3   0     Rennes
# 3  Chelsea  24/11/2020  Group stage  Lampard  Away      W   2   1     Rennes
# 4  Chelsea  02/12/2020  Group stage  Lampard  Away      W   4   0    Sevilla
#
#    Total Passes Completed  ...  Long Passes Completed  Long Passes Attempted  \
# 0                     399  ...                     60                     95
# 1                     637  ...                     84                    112
# 2                     597  ...                     85                    113
# 3                     482  ...                     72                    110
# 4                     379  ...                     59                     89
#
# ...

# %%
df_for_CLPossession = pd.read_csv("ChelseaCL20-21PossessionForMatchStats.csv", encoding='ISO-8859-1')
df_for_CLPossession.head()
# Out:
#       Team        Date        Round  Manager Venue Result  GF  GA   Opponent  \
# 0  Chelsea  20/10/2020  Group stage  Lampard  Home      D   0   0    Sevilla
# 1  Chelsea  28/10/2020  Group stage  Lampard  Away      W   4   0  Krasnodar
# 2  Chelsea  04/11/2020  Group stage  Lampard  Home      W   3   0     Rennes
# 3  Chelsea  24/11/2020  Group stage  Lampard  Away      W   2   1     Rennes
# 4  Chelsea  02/12/2020  Group stage  Lampard  Away      W   4   0    Sevilla
#
#    Possession  ...  Progressive Distnace Of Ball Carries  \
# 0          44  ...                                   847
# 1          70  ...                                  1473
# 2          57  ...                                  1498
# 3          49  ...                                   822
# 4          45  ...                                  1054
#
#    Carries Into Midfield 3rd + Attacking 3rd  \
# 0                                         38
# 1                                         47
# ...
