# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_for_EPLdefense = pd.read_csv("ChelseaEPL20-21DefensiveActionsForMatchStats.csv")
df_for_EPLdefense.head()
# Out:
#          Date        Round  Manager Venue Result   GF   GA        Opponent  \
# 0  14/09/2020  Matchweek 1  Lampard  Away      W  3.0  1.0        Brighton
# 1  20/09/2020  Matchweek 2  Lampard  Home      L  0.0  2.0       Liverpool
# 2  26/09/2020  Matchweek 3  Lampard  Away      D  3.0  3.0       West Brom
# 3  03/10/2020  Matchweek 4  Lampard  Home      W  4.0  0.0  Crystal Palace
# 4  17/10/2020  Matchweek 5  Lampard  Home      D  3.0  3.0     Southampton
#
#    Number Of Players Tackled   Tackles Winning Possession  ...  \
# 0                        20.0                        10.0  ...
# 1                        17.0                        10.0  ...
# 2                        18.0                        14.0  ...
# 3                        16.0                         6.0  ...
# 4                        15.0                         6.0  ...
#
#    Number Of Pressures in Midfield 3rd  Number of Pressures in Attacking 3rd  \
# ...

# %%
import chardet
with open("ChelseaCL20-21DefensiveActionsForMatchStats.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
    
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df_for_CLdefense = pd.read_csv("ChelseaCL20-21DefensiveActionsForMatchStats.csv", encoding='ISO-8859-1')
df_for_CLdefense.head()
# Out:
#       Team        Date        Round  Manager Venue Result  GF  GA   Opponent  \
# 0  Chelsea  20/10/2020  Group stage  Lampard  Home      D   0   0    Sevilla
# 1  Chelsea  28/10/2020  Group stage  Lampard  Away      W   4   0  Krasnodar
# 2  Chelsea  04/11/2020  Group stage  Lampard  Home      W   3   0     Rennes
# 3  Chelsea  24/11/2020  Group stage  Lampard  Away      W   2   1     Rennes
# 4  Chelsea  02/12/2020  Group stage  Lampard  Away      W   4   0    Sevilla
#
#    Number Of Players Tackled   ...  Number Of Pressures in Midfield 3rd  \
# 0                          24  ...                                   63
# 1                          16  ...                                   53
# 2                          17  ...                                   67
# 3                          15  ...                                   55
# 4                          16  ...                                   55
#
#    Number Of Pressures in Attacking 3rd  Number Of Blocks Made  \
# ...
