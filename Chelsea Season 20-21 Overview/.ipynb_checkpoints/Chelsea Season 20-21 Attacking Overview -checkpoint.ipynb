# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_for_EPLattack = pd.read_csv("ChelseaEPL20-21Goal&ShotCreationForMatchStats.csv")
df_for_EPLattack.head()
# Out:
#          Date        Round  Manager Venue Result  GF  GA        Opponent  \
# 0  14/09/2020  Matchweek 1  Lampard  Away      W   3   1        Brighton
# 1  20/09/2020  Matchweek 2  Lampard  Home      L   0   2       Liverpool
# 2  26/09/2020  Matchweek 3  Lampard  Away      D   3   3       West Brom
# 3  03/10/2020  Matchweek 4  Lampard  Home      W   4   0  Crystal Palace
# 4  17/10/2020  Matchweek 5  Lampard  Home      D   3   3     Southampton
#
#    SCA Shot Creating Action(s)   SCA PassLive  ...  SCA Fouls Drawn  \
# 0                            18            15  ...                1
# 1                            10             8  ...                1
# 2                            40            35  ...                3
# 3                            27            21  ...                3
# 4                            19            12  ...                0
#
#    SCA Defensive Action(s)   GCA Goal Creating Action(s)  GCA PassLive  \
# ...

# %%
df_for_CLattack = pd.read_csv("ChelseaCL20-21Goal&ShotCreationForMatchStats.csv", encoding='ISO-8859-1')
df_for_CLattack.head()
# Out:
#       Team        Date        Round  Manager Venue Result  GF  GA   Opponent  \
# 0  Chelsea  20/10/2020  Group stage  Lampard  Home      D   0   0    Sevilla
# 1  Chelsea  28/10/2020  Group stage  Lampard  Away      W   4   0  Krasnodar
# 2  Chelsea  04/11/2020  Group stage  Lampard  Home      W   3   0     Rennes
# 3  Chelsea  24/11/2020  Group stage  Lampard  Away      W   2   1     Rennes
# 4  Chelsea  02/12/2020  Group stage  Lampard  Away      W   4   0    Sevilla
#
#    SCA Shot Creating Action(s)   ...  SCA Fouls Drawn  \
# 0                             9  ...                0
# 1                            23  ...                2
# 2                            14  ...                1
# 3                            17  ...                1
# 4                            25  ...                1
#
#    SCA Defensive Action(s)   GCA Goal Creating Action(s)  GCA PassLive  \
# 0                         0                            0             0
# ...
