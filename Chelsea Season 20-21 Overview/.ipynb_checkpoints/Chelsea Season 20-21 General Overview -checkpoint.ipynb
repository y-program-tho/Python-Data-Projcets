# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_for_EPLgeneral = pd.read_csv("ChelseaEPL20-21GeneralMatchStats.csv")
df_for_EPLgeneral.head()
# Out:
#       Team        Date        Round  Manager Venue Result  GF  GA  \
# 0  Chelsea  14/09/2020  Matchweek 1  Lampard  Away      W   3   1
# 1  Chelsea  20/09/2020  Matchweek 2  Lampard  Home      L   0   2
# 2  Chelsea  26/09/2020  Matchweek 3  Lampard  Away      D   3   3
# 3  Chelsea  03/10/2020  Matchweek 4  Lampard  Home      W   4   0
# 4  Chelsea  17/10/2020  Matchweek 5  Lampard  Home      D   3   3
#
#          Opponent   xG  xGA  Poss
# 0        Brighton  1.2  1.4    47
# 1       Liverpool  1.0  2.6    39
# 2       West Brom  2.2  1.0    75
# 3  Crystal Palace  2.5  0.1    69
# 4     Southampton  2.0  2.2    53

# %%
import chardet
with open("ChelseaCL20-21GeneralMatchStats.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
    
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df_for_CLgeneral = pd.read_csv("ChelseaCL20-21GeneralMatchStats.csv", encoding='ISO-8859-1')
df_for_CLgeneral.head(20)
# Out:
#        Team        Date           Round  Manager Venue Result  GF  GA  \
# 0   Chelsea  20/10/2020     Group stage  Lampard  Home      D   0   0
# 1   Chelsea  28/10/2020     Group stage  Lampard  Away      W   4   0
# 2   Chelsea  04/11/2020     Group stage  Lampard  Home      W   3   0
# 3   Chelsea  24/11/2020     Group stage  Lampard  Away      W   2   1
# 4   Chelsea  02/12/2020     Group stage  Lampard  Away      W   4   0
# 5   Chelsea  08/12/2020     Group stage  Lampard  Home      D   1   1
# 6   Chelsea  23/02/2021     Round of 16   Tuchel  Away      W   1   0
# 7   Chelsea  17/03/2021     Round of 16   Tuchel  Home      W   2   0
# 8   Chelsea  07/04/2021  Quarter finals   Tuchel  Away      W   2   0
# 9   Chelsea  13/04/2021  Quarter finals   Tuchel  Home      L   0   1
# 10  Chelsea  27/04/2021     Semi finals   Tuchel  Away      D   1   1
# 11  Chelsea  05/05/2021     Semi finals   Tuchel  Home      W   2   0
#
#            Opponent   xG  xGA  Poss
# ...
